# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\maxma\Downloads\Online Sales Data.csv")

# %%
data.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    str
#  2   Product Category  240 non-null    str
#  3   Product Name      240 non-null    str
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    str
#  8   Payment Method    240 non-null    str
# dtypes: float64(2), int64(2), str(5)
# memory usage: 17.0 KB

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#        Transaction ID                 Date  Units Sold   Unit Price  \
# count       240.00000                  240  240.000000   240.000000
# mean      10120.50000  2024-04-29 12:00:00    2.158333   236.395583
# min       10001.00000  2024-01-01 00:00:00    1.000000     6.500000
# 25%       10060.75000  2024-02-29 18:00:00    1.000000    29.500000
# 50%       10120.50000  2024-04-29 12:00:00    2.000000    89.990000
# 75%       10180.25000  2024-06-28 06:00:00    3.000000   249.990000
# max       10240.00000  2024-08-27 00:00:00   10.000000  3899.990000
# std          69.42622                  NaN    1.322454   429.446695
#
#        Total Revenue
# count     240.000000
# mean      335.699375
# min         6.500000
# 25%        62.965000
# 50%       179.970000
# 75%       399.225000
# max      3899.990000
# std       485.804469

# %%
data['Product Category'].value_counts()
# Out:
# Product Category
# Electronics        40
# Home Appliances    40
# Clothing           40
# Books              40
# Beauty Products    40
# Sports             40
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# PayPal          80
# Debit Card      40
# Name: count, dtype: int64

# %%
data['Product Name'].value_counts()
# Out:
# Product Name
# Dune by Frank Herbert                              2
# Keurig K-Elite Coffee Maker                        2
# Dyson Supersonic Hair Dryer                        2
# Garmin Forerunner 945                              2
# Sony WH-1000XM4 Headphones                         2
#                                                   ..
# Nespresso Vertuo Next Coffee and Espresso Maker    1
# Nike Air Force 1 Sneakers                          1
# The Handmaid's Tale by Margaret Atwood             1
# Sunday Riley Luna Sleeping Night Oil               1
# Yeti Rambler 20 oz Tumbler                         1
# Name: count, Length: 232, dtype: int64

# %%
data.to_csv("cleaned_Online_Sales_Data.csv, index=False)")

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_theme(style="whitegrid")

# %%
# Group by Category and sum up Total Revenue
category_sales = data.groupby('Product Category')['Total Revenue'].sum().reset_index()
# Create a bar chart
plt.figure(figsize=(10, 5))
sns.barplot(data=category_sales, x='Product Category', y='Total Revenue', palette='viridis')
# Add titles and labels
plt.title('Total Revenue by Product Category', fontsize=14, fontweight='bold')
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Total Revenue ($)', fontsize=12)
# Display the plot
plt.show()
# Out:
# C:\Users\maxma\AppData\Local\Temp\ipykernel_16768\2869809829.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=category_sales, x='Product Category', y='Total Revenue', palette='viridis')
